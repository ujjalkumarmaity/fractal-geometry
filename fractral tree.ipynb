# %%
import matplotlib.pyplot as plt
import math
import random
def rotate(x,y,angle):
    x_point=(x[0]+(math.cos(math.radians(angle)))*(x[1]-x[0]) - math.sin(math.radians(angle))*(y[1]-y[0]))
    y_point=(y[0]+math.sin(math.radians(angle))*(x[1]-x[0]) + math.cos(math.radians(angle))*(y[1]-y[0]))
    return x_point,y_point
def distance(x,y):
    return math.sqrt((x[1]-x[0])**2 + (y[1]-y[0])**2)
def find(x,y,d1,d2):
    ratio=d1/d2
    n_x=(1-ratio)*x[0]+(ratio*x[1])
    n_y=(1-ratio)*y[0]+(ratio*y[1])
    return n_x,n_y

# %%
def tree(x,y,count,angle,n):
    if count>0:
        count-=1
        dis=distance(x,y)
        plt.plot(x,y,linewidth=count+1)
        d1=(dis+(dis/2))
        n_x,n_y=find(x,y,d1,dis)
        x1,y1=rotate([x[1],n_x],[y[1],n_y],angle)
        plt.plot([x[1],x1],[y[1],y1],linewidth=count)
        x2,y2=rotate([x[1],n_x],[y[1],n_y],0-angle)
        plt.plot([x[1],x2],[y[1],y2],linewidth=count)
        tree([x[1],x1],[y[1],y1],count,angle,n)
        tree([x[1],x2],[y[1],y2],count,angle,n)
        #if n==3:
        plt.plot([x[1],n_x],[y[1],n_y],linewidth=count)
        tree([x[1],n_x],[y[1],n_y],count,angle,n)

        
        
    
x=[2,2]
y=[0,6]
angle=45
tree(x,y,6,angle,3)
plt.show()

# %%
import random
random.randrange(2, 4)
# Out:
# 3

# %%
import math
x=1*math.cos(math.radians(90)) - 0*math.sin(math.radians(90))
x
# Out:
# 6.123233995736766e-17

# %%
x′=xcosθ−ysinθ

# %%
y′=ycosθ+xsinθ

# %%
import math 
import matplotlib.pyplot as plt
def rotate(x,y,an):
    an=math.radians(an)
    n_x=x[0]+math.cos(an)*(x[1]-x[0]) - math.sin(an)*(y[1]-y[0])
    n_y=x[0]+math.sin(an)*(x[1]-x[0]) + math.cos(an)*(y[1]-y[0])   
    return n_x,n_y
def dist(x,y):
    return math.sqrt((x[0]-x[1])**2 + (y[0]-y[1])**2)
def find(x,y,d1,d2):
    ratio=d2/d1
    n_x=(1-ratio)*x[0]+(ratio*x[1])
    n_y=(1-ratio)*y[0]+(ratio*y[1])
    return n_x,n_y

# %%
def rotate(x,y,angle):
    x_point=(x[0]+(math.cos(math.radians(angle)))*(x[1]-x[0]) - math.sin(math.radians(angle))*(y[1]-y[0]))
    y_point=(y[0]+math.sin(math.radians(angle))*(x[1]-x[0]) + math.cos(math.radians(angle))*(y[1]-y[0]))
    return x_point,y_point
def dist(x,y):
    return math.sqrt((x[1]-x[0])**2 + (y[1]-y[0])**2)
def find(x,y,d1,d2):
    ratio=d1/d2
    n_x=(1-ratio)*x[0]+(ratio*x[1])
    n_y=(1-ratio)*y[0]+(ratio*y[1])
    return n_x,n_y

# %%
def tree(x,y,count,angle,n):
    if count>0:
        count-=1
        dis=dist(x,y)
        plt.plot(x,y,linewidth=count+1)
        d1=(dis+(dis/2))
        n_x,n_y=find(x,y,d1,dis)
        x1,y1=rotate([x[1],n_x],[y[1],n_y],angle)
        plt.plot([x[1],x1],[y[1],y1],linewidth=count)
        x2,y2=rotate([x[1],n_x],[y[1],n_y],0-angle)
        plt.plot([x[1],x2],[y[1],y2],linewidth=count)
        tree([x[1],x1],[y[1],y1],count,angle,n)
        tree([x[1],x2],[y[1],y2],count,angle,n)
        #if n==3:
        plt.plot([x[1],n_x],[y[1],n_y],linewidth=count)
        tree([x[1],n_x],[y[1],n_y],count,angle,n)

        
        
    
x=[2,2]
y=[0,6]
angle=45
tree(x,y,6,angle,3)
plt.show()
